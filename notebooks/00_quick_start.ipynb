# %% [markdown]
# # Zero-Hardware Embodied AI Project 01\n\n这个 notebook 是免费版最小入口：先检查环境，再下载数据集，最后可视化一个 LeRobot episode。

# %%
from pathlib import Path\nimport os\n\nroot = Path.cwd()\nif not (root / "check_env.py").exists() and (root.parent / "check_env.py").exists():\n    root = root.parent\nos.chdir(root)\nprint(f"Working directory: {root}")

# %% [markdown]
# ## 1. 环境自检

# %%
# !python check_env.py

# %% [markdown]
# ## 2. 下载公开数据集

# %%
# !python scripts/download_dataset.py --repo-id lerobot/pusht

# %% [markdown]
# ## 3. 可视化 episode 0

# %%
# !python scripts/visualize_episode_basic.py --repo-id lerobot/pusht --episode-index 0

# %% [markdown]
# ## 4. 查看输出\n\n运行后在 `assets/` 里查看首帧、action 时序图和 action 分布图；在 `reports/` 里查看 JSON 摘要。
