# %% [markdown]
# # Colab Smoke Test
#
# Run the next cell. If this notebook cannot connect either, the issue is Colab's GitHub-imported notebook/runtime flow rather than this project's dependencies.

# %%
import sys
print('Colab runtime connected')
print(sys.version)
